# %%
# Out:
# Usage:
#   /Users/lhail/Coding Projects /Python/Manning_ML-Project/manning_env/bin/python -m pip <command> [options]
#
# no such option: -m
# Note: you may need to restart the kernel to use updated packages.
